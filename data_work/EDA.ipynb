# %% [markdown]
# # EDA корпуса правил настольных игр
#
# ## Цель
# - Оценить качество исходных текстов после извлечения из PDF/OCR.
# - Оценить качество очищенного корпуса, предназначенного для дальнейшей индексации в RAG.
# - Проанализировать связь характеристик сырых текстов с результатами очистки.
# - Понять, готовы ли очищенные данные к использованию в RAG-системе

# %%
import re
from pathlib import Path
from collections import Counter

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Пути к данным

# %%
METADATA_DIR = Path("metadata")
DOCS_CSV = METADATA_DIR / "docs.csv"
REPORT_CSV = METADATA_DIR / "rules_texts_cleaned_report.csv"

DATA_DIR = Path("data")
RAW_DIR = DATA_DIR / "rules_texts"
CLEAN_GOOD_DIR = DATA_DIR / "rules_texts_cleaned_good"
CLEAN_QUAR_DIR = DATA_DIR / "rules_texts_cleaned_quarantine"

# %% [markdown]
# ## Загрузка таблиц и базовые проверки

# %%
docs = pd.read_csv(DOCS_CSV)
rep = pd.read_csv(REPORT_CSV)

print("docs.csv:", len(docs))
print("rules_texts_cleaned_report.csv:", len(rep))

# Проверка ключей
print("Уникальных doc_sha256 в docs:", docs["doc_sha256"].nunique())
print("Уникальных raw_doc_sha256 в report:", rep["raw_doc_sha256"].nunique())

# Проверка пересечения
docs_set = set(docs["doc_sha256"].astype(str))
rep_set = set(rep["raw_doc_sha256"].astype(str))
print("Пересечение docs и report:", len(docs_set & rep_set))
print("В report, но нет в docs:", len(rep_set - docs_set))
print("В docs, но нет в report:", len(docs_set - rep_set))

print("\nФормат docs.csv")
display(docs.head(3))
print("Формат rules_texts_cleaned_report.csv")
display(rep.head(3))
# Out:
# docs.csv: 2711
# rules_texts_cleaned_report.csv: 2711
# Уникальных doc_sha256 в docs: 2711
# Уникальных raw_doc_sha256 в report: 2711
# Пересечение docs и report: 2711
# В report, но нет в docs: 0
# В docs, но нет в report: 0
#
# Формат docs.csv
#                                           doc_sha256  \
# 0  659dadc07102ef7d251a37ce028ccc168139f86d2c12b2...
# 1  839a212c192c346dcf86e030257c9f3683d8f50f2a9ddf...
# 2  6a8756dbd14b967dd6782fd6a44b59500521ee2c6f77b2...
#
#                   pdf_filename  \
# 0  exploding-kittens-rules.pdf
# 1            imadzhinarium.pdf
# 2             shakal-rules.pdf
#
#                                              pdf_url  \
# 0  https://www.mosigra.ru/download/rules/explodin...
# 1  https://www.mosigra.ru/image/data/mosigra.prod...
# 2  https://www.mosigra.ru/download/rules/shakal-r...
#
#                                            text_path    primary_title lang
# 0  data/rules_texts/659dadc07102ef7d251a37ce028cc...  Взрывные котята   ru
# 1  data/rules_texts/839a212c192c346dcf86e030257c9...     Имаджинариум   ru
# 2  data/rules_texts/6a8756dbd14b967dd6782fd6a44b5...            Шакал   ru
# Формат rules_texts_cleaned_report.csv
#                                       raw_doc_sha256  \
# 0  0003ea7cf163c9f46ccec250538d6534b61e0ae154dccf...
# 1  0016fae7e723b578f4a90da39ef7b89b44005b1b2aae94...
# 2  0069240e8f0166a5794ecddc5d632ea27b15474a2d6733...
#
#                                         clean_sha256  \
# 0  7483a33bfa10cad343ce002a947f10067725762beece79...
# 1  0cbd7f65083e42c5adb927c2ec722a3da15c0f86873477...
# 2  d4c9eed0e0dfbe4ce862a2bd042a675ea5f429a475974e...
#
#                                      clean_text_path lang  \
# 0  data/rules_texts_cleaned_good/0003ea7cf163c9f4...   ru
# 1  data/rules_texts_cleaned_good/0016fae7e723b578...   ru
# 2  data/rules_texts_cleaned_good/0069240e8f0166a5...   ru
#
#                                   pdf_filename  \
# 0  nepostizhimoe-koshmary-iz-puchiny-rules.pdf
# 1  uzhas-arkhjema-tajnoe-poslanie-rules-01.pdf
# 2                            streets_rules.pdf
#
#                                              pdf_url  \
# 0  https://www.mosigra.ru/download/rules/nepostiz...
# 1  https://www.mosigra.ru/download/rules/uzhas-ar...
# 2  https://www.mosigra.ru/download/Правила/street...
#
#                                            text_path  raw_len  clean_len  \
# 0  data/rules_texts/0003ea7cf163c9f46ccec250538d6...    30661      30150
# 1  data/rules_texts/0016fae7e723b578f4a90da39ef7b...    13901      13480
# 2  data/rules_texts/0069240e8f0166a5794ecddc5d632...    29262      28934
#
#    survival_ratio  paragraphs_total  paragraphs_bad  paragraphs_bad_ratio  \
# 0          0.9833                71               2                0.0282
# 1          0.9697                31               0                0.0000
# 2          0.9888                21               0                0.0000
#
#    quarantine
# 0           0
# 1           0
# 2           0

# %% [markdown]
# ## Распределение по языкам

# %%
lang_counts = docs["lang"].fillna("unknown").value_counts()
print("Языки:", ", ".join(f"{k}: {v}" for k, v in lang_counts.items()))
# Out:
# Языки: ru: 2626, en: 85

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=docs, x="lang", order=lang_counts.index)
plt.title("Распределение языков (docs.csv)")
plt.xlabel("Язык")
plt.ylabel("Количество документов")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Часть 1. Анализ сырых текстов
#
# ## Метрики
#
# - `alpha_ratio`: доля буквенных символов среди всех непробельных.
# - `max_char_ratio`: доля наиболее частого символа среди непробельных.
# - `one_letter_lines_ratio`: доля строк, состоящих из одной буквы.
# - `entropy`: энтропия распределения символов.
# - `n_lines`, `raw_chars`: размерности документа.

# %%
RE_ONE_LETTER_LINE = re.compile(r"^\s*[A-Za-zА-Яа-яЁё]\s*$")

def entropy_chars(text: str) -> float:
    s = "".join(ch for ch in text if not ch.isspace())
    if not s:
        return 0.0
    freq = Counter(s)
    n = len(s)
    ent = 0.0
    for c in freq.values():
        p = c / n
        ent -= p * np.log2(p)
    return float(ent)

def raw_metrics(text: str) -> dict:
    chars = [ch for ch in text if not ch.isspace()]
    if not chars:
        return {
            "raw_chars": 0,
            "alpha_ratio": 0.0,
            "max_char_ratio": 1.0,
            "one_letter_lines_ratio": 0.0,
            "entropy": 0.0,
            "n_lines": 0,
        }

    alpha_ratio = sum(ch.isalpha() for ch in chars) / len(chars)
    cnt = Counter(chars)
    max_char_ratio = max(cnt.values()) / len(chars)

    lines = text.splitlines()
    n_lines = len(lines)
    if n_lines:
        one_letter_lines = sum(1 for ln in lines if RE_ONE_LETTER_LINE.match((ln or "").strip()))
        one_letter_lines_ratio = one_letter_lines / n_lines
    else:
        one_letter_lines_ratio = 0.0

    ent = entropy_chars(text)

    return {
        "raw_chars": int(len(chars)),
        "alpha_ratio": float(alpha_ratio),
        "max_char_ratio": float(max_char_ratio),
        "one_letter_lines_ratio": float(one_letter_lines_ratio),
        "entropy": float(ent),
        "n_lines": int(n_lines),
    }

# %% [markdown]
# ## Расчёт метрик по всем документам

# %%
def read_text_safe(path: Path) -> str:
    if not path.exists():
        return ""
    return path.read_text("utf-8", errors="ignore")

rows = []
for _, r in docs.iterrows():
    sha = str(r["doc_sha256"])
    rel_path = str(r.get("text_path", "")).strip()

    path = Path(rel_path) if rel_path else (RAW_DIR / f"{sha}.txt")
    if not path.exists():
        path = RAW_DIR / f"{sha}.txt"

    if not path.exists():
        continue

    raw = read_text_safe(path)
    m = raw_metrics(raw)
    rows.append({
        "doc_sha256": sha,
        "lang": (r.get("lang") or "unknown"),
        "primary_title": (r.get("primary_title") or ""),
        "pdf_url": (r.get("pdf_url") or ""),
        "text_path": (r.get("text_path") or ""),
        **m,
    })

raw_df = pd.DataFrame(rows)
print("Документов с рассчитанными raw-метриками:", len(raw_df))
# Out:
# Документов с рассчитанными raw-метриками: 2711

# %%
fig, ax = plt.subplots(2, 2, figsize=(14, 10))

sns.histplot(data=raw_df, x="alpha_ratio", bins=40, hue="lang", element="step", ax=ax[0, 0])
ax[0,0].set_title("RAW: alpha_ratio")
ax[0,0].set_xlabel("alpha_ratio")
ax[0,0].set_ylabel("Количество документов")

sns.histplot(data=raw_df, x="max_char_ratio", bins=40, hue="lang", element="step", ax=ax[0, 1])
ax[0,1].set_title("RAW: max_char_ratio")
ax[0,1].set_xlabel("max_char_ratio")
ax[0,1].set_ylabel("Количество документов")

sns.histplot(data=raw_df, x="one_letter_lines_ratio", bins=40, hue="lang", element="step", ax=ax[1, 0])
ax[1,0].set_title("RAW: one_letter_lines_ratio")
ax[1,0].set_xlabel("one_letter_lines_ratio")
ax[1,0].set_ylabel("Количество документов")

sns.histplot(data=raw_df, x="entropy", bins=40, hue="lang", element="step", ax=ax[1, 1])
ax[1,1].set_title("RAW: entropy")
ax[1,1].set_xlabel("entropy")
ax[1,1].set_ylabel("Количество документов")

plt.tight_layout()
plt.show()

# %% [markdown]
# Распределение `alpha_ratio` сконцентрировано на высоких значениях (пик около ~0.93–0.96), что означает преобладание буквенных символов в большинстве документов и в целом приемлемую читаемость raw-текста.
#
# Для `max_char_ratio` основная масса документов находится в умеренной области, а правый хвост указывает на небольшую долю документов с высокой повторяемостью одного символа — типичный признак артефактов извлечения/разметки (например, "полосы" из одинаковых символов, разделители, дефекты OCR).
#
# Метрика `one_letter_lines_ratio` у большинства документов близка к нулю, однако наличие редких выбросов говорит о документах, где структура строк нарушена (например, текст "рассыпался" на короткие строки/колонки или появились массовые разрывы строк после OCR).
#
# Значения `entropy` для большинства документов лежат в узком диапазоне, а нетипично низкие значения выступают маркером "неестественного" распределения символов (низкое разнообразие, повторяемость), что также характерно для шумных/повреждённых raw-текстов.

# %% [markdown]
# ## Наиболее проблемные сырые документы
# Рейтинг строится по трём признакам: доля однобуквенных строк, повторяемость символов, доля буквенных символов.

# %%
raw_suspicious = (
    raw_df.sort_values(
        ["one_letter_lines_ratio", "max_char_ratio", "alpha_ratio"],
        ascending=[False, False, True]
    ).head(15)
)

display(raw_suspicious[[
    "doc_sha256", "lang", "primary_title","raw_chars", "n_lines",
    "alpha_ratio", "max_char_ratio", "one_letter_lines_ratio",
    "entropy", "pdf_url", "text_path"
]])
# Out:
#                                              doc_sha256 lang  \
# 2141  7c4ac8e0b0a41c9ea264e2ed5d502034de517d2c60650f...   ru
# 2011  5db7a731cc60ef8f7adab1f6855adcaf8e8be30464de8c...   ru
# 933   4d1a4a1a7ecf54e9e1ca93a2ce5e84e83c8ed3a61cbac2...   ru
# 2304  fb0e199fa1fb39c095978075000d916247e805720f9b01...   ru
# 1208  3a189c9e555e532437b23c8b7bee1825ec5f692f27838b...   ru
# 1794  ca2f2580b910cd577ab84d8b0ec991cd0398039cc85cbe...   ru
# 91    fcd2c49ee8154ce2e41282aa7a068e6fbda2054efe46e3...   ru
# 545   dcc4c1a3d54a854fe0607e741db29eb0ca19fc73fc8bff...   ru
# 777   4b9181d6fec6ceecc2c42db05cbb6fddda6d2c1e7b865d...   ru
# 1068  64d9b3d2e31df83f6bf2e5f18a86a9220412b4828c5b76...   ru
# 1561  cc46817aef998948bf0167bbf9a3fbc054d93ded1dd8ab...   ru
# 1475  4b6fc0323e1632f1bfe74555455b0a3d98c553b730b737...   ru
# 1441  3c814c8a9afd2e1fd442af991a9fe639cbb42ef1744b11...   ru
# 713   40bae8000f2d2fe37050b898bfcb41335a3b4646359208...   ru
# 1453  3c2433036a69156258f00449ffde0087dfcbe929fac999...   ru
#
#                                    primary_title  raw_chars  n_lines  \
# 2141                           Улётные кошмарики       3915      952
# 2011                                 Салат удачи       8622     1230
# 933                        Слово за Слово. Замес       5893      496
# 2304                               Крути педали!      10613      745
# 1208                                        Квич       4687      539
# 1794                                    Ансамбль       5680      312
# 91      Ticket to Ride. Наследие: Легенды Запада      27306     1430
# 545                   ЗлоуМЫШленники [Предзаказ]       9590      653
# 777                                  Слово волка      12839     1043
# 1068                                Тропы Туканы      12836      733
# 1561                 Авалон. Расширенное издание      44471     2625
# 1475                    Селестия. Полное издание      28775     1600
# 1441                              Лучший подарок       2953      102
# 713   Поселенцы. Северные империи. Орды варваров       8383      675
# 1453                                  Скоробуквы       1913      139
#
#       alpha_ratio  max_char_ratio  one_letter_lines_ratio   entropy  \
# 2141     0.928991        0.092465                0.712185  4.947508
# 2011     0.926931        0.098585                0.504065  5.404614
# 933      0.928729        0.093840                0.443548  5.284774
# 2304     0.942994        0.076321                0.367785  5.603505
# 1208     0.896309        0.084276                0.341373  5.140804
# 1794     0.952465        0.113908                0.339744  4.904213
# 91       0.952391        0.091372                0.288112  5.146660
# 545      0.936809        0.098540                0.281776  5.058330
# 777      0.922580        0.097437                0.269415  5.446872
# 1068     0.940402        0.101589                0.259209  5.118972
# 1561     0.942434        0.087450                0.244190  5.145649
# 1475     0.946238        0.092268                0.241875  5.237185
# 1441     0.950220        0.095835                0.235294  4.965259
# 713      0.928665        0.082787                0.228148  5.354562
# 1453     0.933089        0.097229                0.223022  4.957634
#
#                                                 pdf_url  \
# 2141  https://www.mosigra.ru/download/rules/uletnye-...
# 2011  https://www.mosigra.ru/download/Правила/PS_Rul...
# 933   https://www.mosigra.ru/download/rules/slovo-za...
# 2304  https://www.mosigra.ru/image/data/mosigra.prod...
# 1208    https://www.mosigra.ru/download/rules/kvich.pdf
# 1794  https://www.mosigra.ru/download/Правила/EN_rul...
# 91    https://www.mosigra.ru/download/Правила/TTR_Wi...
# 545   https://www.mosigra.ru/download/rules/zloumish...
# 777   https://www.mosigra.ru/download/rules/slovo-vo...
# 1068  https://www.mosigra.ru/download/Правила/Rules_...
# 1561   https://www.mosigra.ru/download/rules/avalon.pdf
# 1475  https://www.mosigra.ru/download/rules/selestia...
# 1441  https://www.mosigra.ru/download/Правила/Pravil...
# 713   https://www.mosigra.ru/download/rules/poselenc...
# 1453  https://www.mosigra.ru/download/rules/skorobyk...
#
#                                               text_path
# 2141  data/rules_texts/7c4ac8e0b0a41c9ea264e2ed5d502...
# 2011  data/rules_texts/5db7a731cc60ef8f7adab1f6855ad...
# 933   data/rules_texts/4d1a4a1a7ecf54e9e1ca93a2ce5e8...
# 2304  data/rules_texts/fb0e199fa1fb39c095978075000d9...
# 1208  data/rules_texts/3a189c9e555e532437b23c8b7bee1...
# 1794  data/rules_texts/ca2f2580b910cd577ab84d8b0ec99...
# 91    data/rules_texts/fcd2c49ee8154ce2e41282aa7a068...
# 545   data/rules_texts/dcc4c1a3d54a854fe0607e741db29...
# 777   data/rules_texts/4b9181d6fec6ceecc2c42db05cbb6...
# 1068  data/rules_texts/64d9b3d2e31df83f6bf2e5f18a86a...
# 1561  data/rules_texts/cc46817aef998948bf0167bbf9a3f...
# 1475  data/rules_texts/4b6fc0323e1632f1bfe74555455b0...
# 1441  data/rules_texts/3c814c8a9afd2e1fd442af991a9fe...
# 713   data/rules_texts/40bae8000f2d2fe37050b898bfcb4...
# 1453  data/rules_texts/3c2433036a69156258f00449ffde0...

# %% [markdown]
# # Часть 2. Анализ результатов очистки
#
# ## Очистка текстов
#
# Очистка корпуса выполнена скриптом `rules_cleaner.py` и включает последовательность этапов нормализации, удаления строковых артефактов и фильтрации абзацев по эвристическим показателям качества.
# На первом этапе текст приводится к единому формату: унифицируются переводы строк, применяется Unicode-нормализация (NFKC), удаляются некоторые невидимые символы (например, soft hyphen, zero-width space, BOM), непечатаемые управляющие символы и пробелы в конце строк.
#
# Далее выполняется построчная очистка: удаляются строки с номерами страниц (шаблоны вида «стр. 3», «page 2»), а также "мусорные" строки (разделители из символов и короткие строки, состоящие только из чисел).
# Дополнительно удаляются последовательности строк из одной буквы или строк, состоящих преимущественно из неалфавитных символов, а также устраняются множественные пробелы.
# Для снижения влияния колонтитулов и повторяющихся служебных фрагментов используется механизм `global boilerplate`: по каждому языку собираются повторяющиеся строки в первых и последних строках документов и затем такие строки удаляются при очистке (параметры `boilerplate_scan_lines`, `boilerplate_min_docs`).
# При наличии переносов слов на дефисе выполняется де-дефисизация: если строка заканчивается дефисом, а следующая строка начинается со слова, то перенос склеивается в единое слово.
#
# После построчной очистки выполняется объединение строк внутри абзацев: строки внутри абзаца склеиваются, а границы сохраняются для списков, заголовков и коротких строк, которые по эвристикам считаются структурными элементами документа.
# Далее текст сегментируется на абзацы как блоки, разделённые пустыми строками, после чего каждый абзац оценивается по показателям `alpha_ratio`, `max_char_ratio` и энтропии; абзацы, не проходящие пороги, удаляются из финального cleaned-текста.
#
# Документ помечается флагом `quarantine`, если очищенный текст пустой, либо коэффициент сохранения `survival_ratio` ниже порога (`min_survival_ratio=0.5`), либо доля удалённых абзацев `paragraphs_bad_ratio` превышает порог (`max_bad_paragraph_ratio = 0.4`).
# ​
#
#
#
# ## Метрики
#
# - `raw_len`: длина исходного текста после нормализации (число символов).
# - `clean_len`: длина очищенного текста (число символов).
# - `survival_ratio`: коэффициент сохранения текста, доля (clean_len / raw_len).
# - `paragraphs_total`: число абзацев в нормализованном тексте перед фильтрацией по качеству (абзац определяется как блок текста между пустыми строками).
# - `paragraphs_bad`: число абзацев, отфильтрованных как низкокачественные по эвристикам (например, низкая доля букв, высокая повторяемость символов и т.п.).
# - `paragraphs_bad_ratio`: доля отфильтрованных абзацев, (paragraphs_bad / paragraphs_total).

# %% [markdown]
# ## Доля карантина

# %%
print(f"Доля документов в карантине: {rep['quarantine'].mean():.3f} ({(rep['quarantine']==1).sum()}/{len(rep)})")
# Out:
# Доля документов в карантине: 0.007 (20/2711)

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=rep, x="quarantine")
plt.title("Распределение quarantine")
plt.xlabel("quarantine (0/1)")
plt.ylabel("Количество документов")
plt.tight_layout()
plt.show()

# %% [markdown]
# По результатам очистки доля документов, отправленных в карантин, составляет ~0.7%: 20 из 2711, то есть подавляющее большинство документов проходит quality gate.

# %%
rep2 = rep.merge(
    docs[["doc_sha256", "primary_title"]],
    left_on="raw_doc_sha256",
    right_on="doc_sha256",
    how="left"
).drop(columns=["doc_sha256"])

# %% [markdown]
# ## Распределение `survival_ratio` и `paragraphs_bad_ratio`

# %%
fig, ax = plt.subplots(2, 2, figsize=(14, 8))

sns.histplot(data=rep2, x="survival_ratio", bins=40, ax=ax[0, 0])
ax[0][0].set_title("Распределение survival_ratio")
ax[0][0].set_xlabel("clean_len / raw_len")
ax[0][0].set_ylabel("Количество документов")
ax[0, 0].set_xlim(0.7, 1.0)

sns.boxplot(data=rep2, x="lang", y="survival_ratio", ax=ax[0, 1])
ax[0][1].set_title("survival_ratio по языкам")
ax[0][1].set_xlabel("Язык")
ax[0][1].set_ylabel("clean_len / raw_len")

sns.histplot(data=rep2, x="paragraphs_bad_ratio", bins=40, ax=ax[1, 0])
ax[1][0].set_title("Распределение paragraphs_bad_ratio")
ax[1][0].set_xlabel("paragraphs_bad_ratio")
ax[1][0].set_ylabel("Количество документов")
ax[1, 0].set_xlim(0.0, 0.75)

sns.boxplot(data=rep2, x="lang", y="paragraphs_bad_ratio", ax=ax[1, 1])
ax[1][1].set_title("paragraphs_bad_ratio по языкам")
ax[1][1].set_xlabel("Язык")
ax[1][1].set_ylabel("paragraphs_bad_ratio")

plt.tight_layout()
plt.show()

# %% [markdown]
# Распределение `survival_ratio` сильно смещено к 1: для большинства документов длина cleaned-текста почти равна длине нормализованного raw-текста, то есть очистка удаляет сравнительно немного символов и в основном шум, а не полезный контент.
#
# По boxplot видно, что медианные значения `survival_ratio` очень высокие и сопоставимы между `ru` и `en`, а редкие низкие значения встречаются как выбросы.
#
# Распределение `paragraphs_bad_ratio` имеет выраженную массу у нуля: значительная часть документов проходит абзацную фильтрацию практически без потерь, что говорит о достаточно хорошем качестве извлечённого текста и адекватных порогах эвристик.
#
# При этом присутствует длинный хвост по `paragraphs_bad_ratio` (до высоких значений на графике), что указывает на небольшую долю документов, где значимая часть абзацев распознана как плохие и удалена.

# %% [markdown]
# ## Документы с наихудшим сохранением текста

# %%
worst = rep2.sort_values("survival_ratio").head(15)[[
    "raw_doc_sha256", "clean_sha256", "lang", "primary_title",
    "raw_len", "clean_len", "survival_ratio",
    "paragraphs_bad_ratio", "quarantine",
    "pdf_url", "text_path", "clean_text_path"
]]
display(worst)
# Out:
#                                          raw_doc_sha256  \
# 1454  8ad40d5f1c52538a1110ab3026513667a684cdcccce986...
# 326   20baad64474752bc30889a6d8a84b804f16811c0e987c8...
# 1294  7c4ac8e0b0a41c9ea264e2ed5d502034de517d2c60650f...
# 1729  a593d33a1d83d44dc611e5c062e0c8dea21c889a1e8cb4...
# 2575  f46d3ebbf5e2d4612f86a6e4caf94f9751cc65b9fe4e45...
# 373   262fc8daa5759d0ddcda3320fe2e3fe7e8cb2b8a23d786...
# 493   31c8144d00f292583cbf15d46ed4110581b9331b350b14...
# 1613  9a4722f17abb05abf472c0bb50fb3ba79234cf1b09a62b...
# 280   1b5c849de3b9be0801f80ed84b10f235bbde1108f31c39...
# 1790  aa74ddb623625cc4595ca74b36a6d5b4f67a6192dccafa...
# 631   3dbc1878e3e867609e309314553a67f82fb5de8d257755...
# 817   4d3cfec930c5513a27888eee0e1aa5de3d40bc4aafa805...
# 122   0b5b0f15b709d6728faf3de5e1648b93a1fe148deedc56...
# 1249  78611f3484e221f9ced725c84a4f6511f3208b392ff1d4...
# 990   5dd95ce78e389cc64cd8318074bc0338c58bd45fc42367...
#
#                                            clean_sha256 lang  \
# 1454  2a37d62e71e2f09d873b9b0b2aaa68f2330f769ba19ef6...   ru
# 326   108df5c28ad8878156588b9b4a133bfa0bd0f4e983a3c9...   ru
# 1294  77e6dabe911c8bfd88e84f53377761af74446f8066d90f...   ru
# 1729  0c43f1197826a76ad86aecac2f84102b907d9da6bda979...   ru
# 2575  31bdf41f9a46bd71a91eccb93da50ac46b9115c1a820eb...   ru
# 373   31bdf41f9a46bd71a91eccb93da50ac46b9115c1a820eb...   ru
# 493   e9baca860f4564e42af40be7ea0a22a266bdc65d8f486e...   ru
# 1613  c4b9867fc7b91d632cf50182b93ca4540fdd90d5f776d6...   ru
# 280   80ac3225dcdb3b86c0ffb991a74468d1213fdb6457bf6b...   ru
# 1790  de3a651dd23c4547f26fff393d191e50312a019b62da85...   ru
# 631   f167ee704bea1873c1e0a4d66efe59db8038feb26ec03a...   ru
# 817   64d4fc2dbfcb5dae2c83ea66ce5ba4ad95fc0e22e2c05e...   ru
# 122   e41b78950a840dad3ff8d63630eb0b87622d8a62b2900f...   ru
# 1249  d06652d09554c74c289d9ca16ecaa25f322ba96dc12ce2...   ru
# 990   c5b3c6cad4bf051982cbf3e9aae36f020c17e000682380...   ru
#
#                                           primary_title  raw_len  clean_len  \
# 1454           Опасные гости: кто убил мистера Уолтона?    42529      25933
# 326                                                Заяц     9526       6877
# 1294                                  Улётные кошмарики     5393       3911
# 1729                    Динозавры. Таинственные острова     1999       1488
# 2575                              Конверсейшн. Девичник      533        398
# 373                                 Конверсейшн. Друзья      531        398
# 493                                        Время Валеры      571        434
# 1613                  Магнитная игра Тангос Ноев Ковчег      544        415
# 280                                  Взлом: Ночи кабуки     7294       5590
# 1790                                Кортекс 2 для детей     2567       2022
# 631                Войны Чёрной Розы: Возрождение. Юкас     5364       4244
# 817                                        Зачарованная    25256      20001
# 122                            Анх. Боги Египта. Фараон    14776      11742
# 1249                                            7 семей     2993       2382
# 990   Oathsworn: Верные клятве. Тайны Темнолесья. Ар...      942        759
#
#       survival_ratio  paragraphs_bad_ratio  quarantine  \
# 1454          0.6098                0.2619           0
# 326           0.7219                0.1765           0
# 1294          0.7252                0.2083           0
# 1729          0.7444                0.5294           1
# 2575          0.7467                0.0000           0
# 373           0.7495                0.0000           0
# 493           0.7601                0.0000           0
# 1613          0.7629                0.2000           0
# 280           0.7664                0.1250           0
# 1790          0.7877                0.3750           0
# 631           0.7912                0.1429           0
# 817           0.7919                0.0769           0
# 122           0.7947                0.0714           0
# 1249          0.7959                0.3333           0
# 990           0.8057                0.4211           1
#
#                                                 pdf_url  \
# 1454  https://www.mosigra.ru/download/Правила/01460.pdf
# 326     https://www.mosigra.ru/download/rules/zaiac.pdf
# 1294  https://www.mosigra.ru/download/rules/uletnye-...
# 1729  https://www.mosigra.ru/download/files/ВВ1889 д...
# 2575  https://www.mosigra.ru/image/data/mosigra.prod...
# 373   https://www.mosigra.ru/image/data/mosigra.prod...
# 493   https://www.mosigra.ru/image/data/mosigra.othe...
# 1613  https://www.mosigra.ru/image/data/mosigra.prod...
# 280   https://www.mosigra.ru/download/rules/vzlom-no...
# 1790  https://www.mosigra.ru/image/data/mosigra.prod...
# 631   https://www.mosigra.ru/download/rules/rules-vc...
# 817   https://www.mosigra.ru/download/rules/zacharov...
# 122   https://www.mosigra.ru/download/Правила/Pravil...
# 1249  https://www.mosigra.ru/image/data/mosigra.prod...
# 990   https://www.mosigra.ru/download/rules/oathswor...
#
#                                               text_path  \
# 1454  data/rules_texts/8ad40d5f1c52538a1110ab3026513...
# 326   data/rules_texts/20baad64474752bc30889a6d8a84b...
# 1294  data/rules_texts/7c4ac8e0b0a41c9ea264e2ed5d502...
# 1729  data/rules_texts/a593d33a1d83d44dc611e5c062e0c...
# 2575  data/rules_texts/f46d3ebbf5e2d4612f86a6e4caf94...
# 373   data/rules_texts/262fc8daa5759d0ddcda3320fe2e3...
# 493   data/rules_texts/31c8144d00f292583cbf15d46ed41...
# 1613  data/rules_texts/9a4722f17abb05abf472c0bb50fb3...
# 280   data/rules_texts/1b5c849de3b9be0801f80ed84b10f...
# 1790  data/rules_texts/aa74ddb623625cc4595ca74b36a6d...
# 631   data/rules_texts/3dbc1878e3e867609e309314553a6...
# 817   data/rules_texts/4d3cfec930c5513a27888eee0e1aa...
# 122   data/rules_texts/0b5b0f15b709d6728faf3de5e1648...
# 1249  data/rules_texts/78611f3484e221f9ced725c84a4f6...
# 990   data/rules_texts/5dd95ce78e389cc64cd8318074bc0...
#
#                                         clean_text_path
# 1454  data/rules_texts_cleaned_good/8ad40d5f1c52538a...
# 326   data/rules_texts_cleaned_good/20baad64474752bc...
# 1294  data/rules_texts_cleaned_good/7c4ac8e0b0a41c9e...
# 1729  data/rules_texts_cleaned_quarantine/a593d33a1d...
# 2575  data/rules_texts_cleaned_good/f46d3ebbf5e2d461...
# 373   data/rules_texts_cleaned_good/262fc8daa5759d0d...
# 493   data/rules_texts_cleaned_good/31c8144d00f29258...
# 1613  data/rules_texts_cleaned_good/9a4722f17abb05ab...
# 280   data/rules_texts_cleaned_good/1b5c849de3b9be08...
# 1790  data/rules_texts_cleaned_good/aa74ddb623625cc4...
# 631   data/rules_texts_cleaned_good/3dbc1878e3e86760...
# 817   data/rules_texts_cleaned_good/4d3cfec930c5513a...
# 122   data/rules_texts_cleaned_good/0b5b0f15b709d672...
# 1249  data/rules_texts_cleaned_good/78611f3484e221f9...
# 990   data/rules_texts_cleaned_quarantine/5dd95ce78e...

# %% [markdown]
# В топ‑15 документов с минимальным `survival_ratio` значения опускаются примерно до `~0.61` и выше, то есть для небольшой доли корпуса очистка удаляет заметную часть символов.
#
# При выбранных порогах quality‑gate (`min_survival_ratio=0.5`, `max_bad_paragraph_ratio=0.4`) часть документов из хвоста дополнительно маркируется как `quarantine=1`; в показанной выборке это документы с повышенной долей отфильтрованных абзацев (например, `paragraphs_bad_ratio около ~0.53 и ~0.42`).
#
# Таким образом, quarantine‑фильтр работает как защита RAG‑индекса: он отсекает случаи, где очистка вынуждена удалять значимую долю абзацев и итоговый текст потенциально становится фрагментированным/шумным, даже если `survival_ratio` ещё остаётся выше минимального порога.

# %% [markdown]
# ## Связь raw-метрик и результатов очистки

# %%
cmp = raw_df.merge(
    rep2[["raw_doc_sha256", "survival_ratio", "paragraphs_bad_ratio", "quarantine"]],
    left_on="doc_sha256",
    right_on="raw_doc_sha256",
    how="left"
).drop(columns=["raw_doc_sha256"])

# %%
raw_cols = ["alpha_ratio", "max_char_ratio", "one_letter_lines_ratio", "entropy"]
clean_cols = ["survival_ratio", "paragraphs_bad_ratio"]

corr = cmp[raw_cols + clean_cols].corr(method="spearman")
block = corr.loc[raw_cols, clean_cols]

plt.figure(figsize=(8, 4))
sns.heatmap(
    block,
    cmap="RdBu_r",
    vmin=-1, vmax=1, center=0,
    annot=True, fmt=".2f",
    linewidths=0.5,
    cbar_kws={"label": "Spearman p"}
)
plt.title("Spearman: связь RAW-метрик и результатов очистки")
plt.tight_layout()
plt.show()

# %% [markdown]
# Наиболее выраженная связь с результатом очистки наблюдается у `alpha_ratio`: чем выше доля буквенных символов в raw, тем выше `survival_ratio`, то есть тем больше текста сохраняется после очистки.
#
# Для `max_char_ratio` связь с `paragraphs_bad_ratio` практически отсутствует, а с `survival_ratio` слабоположительная. Это может означать, что повышенная повторяемость символов встречается не только в "мусорных" фрагментах, но и в нормальных структурах текста (например, форматирование/разделители), поэтому по этой метрике трудно надёжно предсказывать долю удалённых абзацев.
#
# `entropy` показывает отрицательную связь с `survival_ratio` и положительную с `paragraphs_bad_ratio`, то есть документы с более высокой энтропией в сыром тексте в среднем сохраняют меньше символов и чаще имеют большую долю отфильтрованных абзацев.
#
# **Корреляции отражают монотонные ассоциации и не доказывают причинно‑следственную связь; часть потерь может объясняться специфическими артефактами PDF/OCR, которые не полностью описываются raw‑метриками.**

# %% [markdown]
# ## Анализ cleaned-текстов (GOOD)
# Анализ выполняется для документов, не отправленных в карантин.

# %%
rep_good = rep2[rep2["quarantine"] == 0].copy()
print("GOOD документов:", len(rep_good))

def load_clean_text(row) -> str:
    path = str(row.get("clean_text_path") or "").strip()
    if not path:
        return ""
    return read_text_safe(Path(path))

text_df = rep_good[[
    "raw_doc_sha256",
    "clean_sha256",
    "lang",
    "primary_title",
    "pdf_url",
    "clean_text_path"
]].copy()
text_df["text"] = text_df.apply(load_clean_text, axis=1)
text_df["text_len_chars"] = text_df["text"].str.len()

print("Пустых текстов в GOOD:", int((text_df["text_len_chars"] == 0).sum()))
# Out:
# GOOD документов: 2691
# Пустых текстов в GOOD: 0

# %% [markdown]
# ### Распределение длины cleaned-документов

# %%
TOKEN_RE = re.compile(
    r"(?:"
    r"[A-Za-zА-Яа-яЁё]+(?:-[A-Za-zА-Яа-яЁё]+)*" # слова, включая дефисные
    r"|\d+(?:\.\d+){1,6}" # секции: 1.2.3
    r"|\d+(?:[.,]\d+)?(?:[–-]\d+(?:[.,]\d+)?)?" # числа и диапазоны: 2, 2.5, 2–4, 1-3
    r")",
    re.UNICODE,
)
SENT_RE = re.compile(r"(?<!\d)[.!?]+(?!\d)(?=(?:\s|$))")


def get_tokens(text: str) -> list[str]:
    return [t.lower() for t in TOKEN_RE.findall(text)]


text_df["tokens"] = text_df["text"].map(get_tokens)
text_df["n_tokens"] = text_df["tokens"].map(len)
text_df["n_sents"] = text_df["text"].map(lambda s: len([x for x in SENT_RE.split(s) if x.strip()]))

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 8))

sns.histplot(data=text_df, x="text_len_chars", hue="lang", bins=60, element="step", ax=ax[0, 0])
ax[0][0].set_title("CLEANED (GOOD): длина документов в символах")
ax[0][0].set_xlabel("n_chars")
ax[0][0].set_ylabel("Количество документов")

sns.histplot(data=text_df, x="n_tokens", hue="lang", bins=60, element="step", ax=ax[0, 1])
ax[0][1].set_title("CLEANED (GOOD): длина документов в токенах")
ax[0][1].set_xlabel("n_tokens")
ax[0][1].set_ylabel("Количество документов")

sns.histplot(data=text_df, x="n_sents", hue="lang", bins=60, element="step", ax=ax[1, 0])
ax[1][0].set_title("CLEANED (GOOD): количество предложений (грубая оценка)")
ax[1][0].set_xlabel("n_sents")
ax[1][0].set_ylabel("Количество документов")

sns.boxplot(data=text_df, x="lang", y="n_tokens", ax=ax[1, 1])
ax[1][1].set_title("CLEANED (GOOD): количество токенов по языкам")
ax[1][1].set_xlabel("Язык")
ax[1][1].set_ylabel("n_tokens")

plt.tight_layout()
plt.show()

# %% [markdown]
# Длины очищенных документов в символах и word‑like токенах распределены с выраженным длинным хвостом: основная масса документов короткая/средняя, но присутствуют редкие очень большие правила.
#
# Оценка числа предложений также имеет длинный хвост, но её корректнее интерпретировать как число сегментов/границ предложений по эвристике, потому что форматирование (списки, оглавления) может завышать счётчик даже при более "умных" сегментаторах.
#
# По boxplot видно, что количество токенов у en в среднем выше, чем у ru, однако выборка en существенно меньше.

# %% [markdown]
# ### Лексические характеристики
# Рассчитываются размер словаря и type-token ratio (TTR) по языкам.

# %%
def vocab_stats(sub: pd.DataFrame) -> dict:
    all_tokens = [t for toks in sub["tokens"] for t in toks]
    if not all_tokens:
        return {"n_docs": int(len(sub)), "n_tokens": 0, "vocab_size": 0, "ttr": 0.0}
    vocab = set(all_tokens)
    return {
        "n_docs": int(len(sub)),
        "n_tokens": int(len(all_tokens)),
        "vocab_size": int(len(vocab)),
        "ttr": float(len(vocab) / len(all_tokens)),
    }

stats = []
for lang, sub in text_df.groupby("lang"):
    s = vocab_stats(sub)
    s["lang"] = lang
    stats.append(s)

vocab_df = pd.DataFrame(stats)[[
    "lang",
    "n_docs",
    "n_tokens",
    "vocab_size",
    "ttr"
]].sort_values("n_docs", ascending=False)
display(vocab_df)
# Out:
#   lang  n_docs  n_tokens  vocab_size       ttr
# 1   ru    2607   8088449      221721  0.027412
# 0   en      84    543663       17887  0.032901

# %% [markdown]
# Размер словаря на русском языке значительно выше по сравнению с английским, что ожидаемо из‑за большего объёма текста и морфологического разнообразия русского языка.
#
# TTR (type-token ratio) низкий в обеих группах, что указывает на сильную повторяемость лексики в правилах (типовые формулировки, повтор терминов, структуры "ход/фаза/игрок/карта" и т.д.).

# %% [markdown]
# ## Вывод по результатам очистки
#
# Очищенный корпус (GOOD) пригоден для дальнейшей подготовки к индексации: тексты нормализованы, метрики очистки показывают стабильное качество, а распределения длины имеют ожидаемый длинный хвост, который требует разбиения документов на чанки перед загрузкой в векторную БД.
